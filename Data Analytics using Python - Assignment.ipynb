# %%
# 1)	Please take care of missing data present in the “Data.csv” file using python module “sklearn.impute” and its methods, 
# also collect all the data that has “Salary” less than “70,000”.

import pandas as pd
from sklearn.impute import SimpleImputer
df = pd.read_csv("C:/Users/RamyaRajaLakshmi/Downloads/Python/7.Data Analytics Using Python/Data sets/Data.csv")
# Create an instance of SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
#most_frequent method replaces missing values with the most frequent value occurring in the corresponding feature/column.
imputer = imputer.fit(df)
df_updated = pd.DataFrame(imputer.transform(df), columns=df.columns)
print(df_updated)
df_updated.to_csv("C:/Users/RamyaRajaLakshmi/Downloads/Python/7.Data Analytics Using Python/Data sets/Updated_Data.csv", index=False)

df_new = pd.read_csv("C:/Users/RamyaRajaLakshmi/Downloads/Python/7.Data Analytics Using Python/Data sets/Updated_Data.csv")
output = df_new[df_new['Salaries'] < 70000]
print(output)
output.to_csv("C:/Users/RamyaRajaLakshmi/Downloads/Python/7.Data Analytics Using Python/Data sets/salary_new.csv")
# Out:
#                      Position State Sex MaritalDesc CitizenDesc  \
# 0                Accountant I    MA   F     Married  US Citizen
# 1                Accountant I    MA  M     Divorced  US Citizen
# 2                Accountant I    MA  M       Single  US Citizen
# 3    Administrative Assistant    MA   F      Single  US Citizen
# 4     Production Technician I    MA   F      Single  US Citizen
# ..                        ...   ...  ..         ...         ...
# 305      Sr. Network Engineer    CT   F     Married  US Citizen
# 306      Sr. Network Engineer    MA  M      Married  US Citizen
# 307   Production Technician I    MA  M      Married  US Citizen
# 308      Sr. Network Engineer    CT  M       Single  US Citizen
# 309      Sr. Network Engineer    MA   F     Widowed  US Citizen
#
#          EmploymentStatus     Department  Salaries   age  \
# 0                  Active  Admin Offices    674.28  41.0
# 1                  Active  Admin Offices    674.28  50.0
# ...

# %%
# 2)	Subtracting dates: 
# Python date objects let us treat calendar dates as something similar to numbers: we can compare them, sort them, add, 
# and even subtract them. Do math with dates in a way that would be a pain to do by hand. The 2007 Florida hurricane season was one of the busiest on record, with 8 hurricanes in one year. 
# The first one hit on May 9th, 2007, and the last one hit on December 13th, 2007. How many days elapsed between the first and last hurricane in 2007?

from datetime import date

start = date(2007, 5, 9)
end = date(2007, 12, 13)
elapsed_days = (end - start).days #timedelta object representing the duration between the two dates
print("The number of days in the resulting timedelta object is %d"%(elapsed_days))
# Out:
# The number of days in the resulting timedelta object is 218

# %%
# 3)	Representing dates in different ways
# Date objects in Python have a great number of ways they can be printed out as strings. In some cases, you want to know the date in a clear, language-agnostic format. In other cases, you want something which can fit into a paragraph and flow naturally.
# Print out the same date, August 26, 1992 (the day that Hurricane Andrew made landfall in Florida), in a number of different ways, by using the “ .strftime() ” method. Store it in a variable called “Andrew”. 
# Instructions: Print it in the format 'YYYY-MM', 'YYYY-DDD' and 'MONTH (YYYY)'

from datetime import datetime

Andrew = []
date_str = "August 26, 1992"
a = datetime.strptime(date_str,"%B %d, %Y")
date_1 = a.strftime("%Y-%m")
date_2 = a.strftime("%Y-%j")
date_3 = a.strftime("%B (%Y)")
n = (date_1,date_2,date_3)
for i in n:
    Andrew.append(i)

print(Andrew)
# Out:
# ['1992-08', '1992-239', 'August (1992)']

# %%
# 4)	For the dataset “Indian_cities”, 
# a)	Find out top 10 states in female-male sex ratio

import pandas as pd
import numpy as np
df = pd.read_csv("C:/Users/RamyaRajaLakshmi/Downloads/Python/7.Data Analytics Using Python/Data sets/Indian_cities.csv")
sort = df.sort_values("sex_ratio", ascending = False)
output = sort[["state_name","sex_ratio"]]
final_ratio = output.head(10).reset_index(drop = True)

print(final_ratio)
# Out:
#        state_name  sex_ratio
# 0          KERALA       1093
# 1          KERALA       1077
# 2          KERALA       1076
# 3          KERALA       1076
# 4          KERALA       1064
# 5        MANIPUR        1055
# 6          KERALA       1053
# 7  ANDHRA PRADESH       1046
# 8      PUDUCHERRY       1045
# 9       MEGHALAYA       1042

# %%
# b)	Find out top 10 cities in total number of graduates

sort_1 = df.sort_values("total_graduates", ascending = False)
output_1 = sort_1[["name_of_city","total_graduates"]]
f = output_1.head(10).reset_index(drop = True)
print(f)
# Out:
#          name_of_city  total_graduates
# 0              Delhi           2221137
# 1     Greater Mumbai           1802371
# 2           Bengaluru          1591163
# 3  Greater Hyderabad           1164149
# 4            Chennai            879695
# 5            Kolkata            818476
# 6          Ahmadabad            769858
# 7               Pune            656508
# 8            Lucknow            596990
# 9             Jaipur            533148

# %%
#c)	Find out top 10 cities and their locations in respect of  total effective_literacy_rate.


sort_2 = df.sort_values("effective_literacy_rate_total", ascending = False)
output_2 = sort_2[["name_of_city","location","effective_literacy_rate_total"]]
f1 = output_2.head(10).to_string(index=False)
print(f1)
# Out:
#      name_of_city              location  effective_literacy_rate_total
#           Aizawl   23.727107,92.7176389                          98.80
#            Kochi   9.9312328,76.2673041                          97.49
#         Thrissur  10.5276416,76.2144349                          97.24
#        Kozhikode    11.2587531,75.78041                          96.80
#        Alappuzha   9.4980667,76.3388484                          96.56
#         Khardaha  22.7002943,88.3753455                          95.50
#        Nagercoil   8.1832857,77.4118996                          95.35
#          Alandur  12.9974873,80.2006371                          95.15
# North Barrackpur   22.7902358,88.367179                          94.78
#           Shimla  31.1048145,77.1734033                          94.67

# %%
#5)	 For the data set “Indian_cities”
#a)	Construct histogram on literates_total and comment about the inferences

import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("C:/Users/RamyaRajaLakshmi/Downloads/Python/7.Data Analytics Using Python/Data sets/Indian_cities.csv")

plt.hist(df.literates_total, bins = 50, edgecolor='black', color = '#39FF14')
plt.xlabel("Total Literates")
plt.ylabel("Frequency")
plt.title("Histogram of Literates Total")
# Out:
# Text(0.5, 1.0, 'Histogram of Literates Total')

# %%
#b)	Construct scatter  plot between  male graduates and female graduates

import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("C:/Users/RamyaRajaLakshmi/Downloads/Python/7.Data Analytics Using Python/Data sets/Indian_cities.csv")

plt.scatter(df.male_graduates,df.female_graduates, edgecolor='blue', color = '#39FF14')
plt.xlabel("Male Graduates")
plt.ylabel("Female Graduates")
plt.title("Scatter Plot between Male and Female Graduates")
# Out:
# Text(0.5, 1.0, 'Scatter Plot between Male and Female Graduates')

# %%
#6)	 For the data set “Indian_cities”
#a)	Construct Boxplot on total effective literacy rate and draw inferences

import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("C:/Users/RamyaRajaLakshmi/Downloads/Python/7.Data Analytics Using Python/Data sets/Indian_cities.csv")
plt.boxplot(df.effective_literacy_rate_total)
plt.title("Total Effective Literacy Rate")
plt.ylabel("Literacy Rate")
# Out:
# Text(0, 0.5, 'Literacy Rate')

# %%
#b)	Find out the number of null values in each column of the dataset and delete them.

import pandas as pd
df = pd.read_csv("C:/Users/RamyaRajaLakshmi/Downloads/Python/7.Data Analytics Using Python/Data sets/Indian_cities.csv")
df.isnull().sum() #no null values are found in a given dataset
# Out:
# name_of_city                      0
# state_code                        0
# state_name                        0
# dist_code                         0
# population_total                  0
# population_male                   0
# population_female                 0
# 0-6_population_total              0
# 0-6_population_male               0
# 0-6_population_female             0
# literates_total                   0
# literates_male                    0
# literates_female                  0
# sex_ratio                         0
# child_sex_ratio                   0
# effective_literacy_rate_total     0
# effective_literacy_rate_male      0
# effective_literacy_rate_female    0
# location                          0
# total_graduates                   0
# male_graduates                    0
# female_graduates                  0
# dtype: int64
